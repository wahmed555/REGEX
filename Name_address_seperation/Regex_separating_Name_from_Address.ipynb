# %%
import pandas as pd
import numpy as np

# %%
import re

# %%
# reading the Data

df0= pd.read_excel('bewelldexter_rev0.xlsx',sheet_name='Sheet1 (2)',header=None)
# df1=df0[1]
df1=df0[:]   # copying data into a new dataframe
df1
# Out:
#      0                                                  1
# 0  NaN                                                NaN
# 1  NaN                                                NaN
# 2  NaN  Hush Vapor1908 E Colfax AveDenver CO 80206Unit...
# 3  NaN                                                NaN
# 4  NaN  Karmaceuticals4 S Santa Fe DrDenver CO 80233Un...
# 5  NaN                                                NaN
# 6  NaN  Lush2490 W 2nd AvenueDenver CO 80223United States
# 7  NaN                                                NaN
# 8  NaN  Herbal Daze4530 E Colfax AveDenver CO 80220Uni...
# 9  NaN                                                NaN
# 10 NaN  Maximum Headshop1832 S BroadwayDenver CO 80210...
# 11 NaN                                                NaN
# 12 NaN  Highland Massage Company5110 W 38th AveDenver ...
# 13 NaN                                                NaN
# 14 NaN  VaporCore2120 S Broadway Unit GDenver CO 80210...
# ...

# %%
dfA=df1.dropna(how="all")
dfA
# Out:
#      0                                                  1
# 2  NaN  Hush Vapor1908 E Colfax AveDenver CO 80206Unit...
# 4  NaN  Karmaceuticals4 S Santa Fe DrDenver CO 80233Un...
# 6  NaN  Lush2490 W 2nd AvenueDenver CO 80223United States
# 8  NaN  Herbal Daze4530 E Colfax AveDenver CO 80220Uni...
# 10 NaN  Maximum Headshop1832 S BroadwayDenver CO 80210...
# 12 NaN  Highland Massage Company5110 W 38th AveDenver ...
# 14 NaN  VaporCore2120 S Broadway Unit GDenver CO 80210...
# 16 NaN  Speedy Mart1645 E EvansDenver CO 80210United S...
# 18 NaN  Cultivated Hemp6117 W 38th AveWheat Ridge CO 8...
# 20 NaN  Dragon Headz1695 Wadsworth Blvd # BLakewood CO...
# 22 NaN  theCLOUDS vape shop and hookah lounge – Kratom...
# 24 NaN  Canna World Market1420 S Wadsworth BlvdLakewoo...
# 26 NaN  Payless Tobacco in Arvada6385 Wadsworth BlvdAr...
# 28 NaN  The Pipe Shop – Westminster7530 Sheridan Boule...
# 30 NaN  Reflections Salon and Spa980 Simms StGolden CO...
# ...

# %%
dfA['3s']=''
dfA['4s']=''
# Out:
# C:\ProgramData\Anaconda6\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda6\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in range(0,len(dfA[1])):
    k=dfA.iloc[i,1]
    print(k)
    x=re.findall('^[A-z \s]+',k)
#     x=re.findall('^[A-z \s]+ ',k)
    if len(x)==0:
        x=" NO Name detected at :"+ str(i)
    dfA.iloc[i,2]=x
    y=re.findall('[\d]+ [A-z \s]+',k)
    dfA.iloc[i,3]=y
#     print(x)
#     print(y)
dfA
# Out:
# Hush Vapor1908 E Colfax AveDenver CO 80206United States
# Karmaceuticals4 S Santa Fe DrDenver CO 80233United States
# Lush2490 W 2nd AvenueDenver CO 80223United States
# Herbal Daze4530 E Colfax AveDenver CO 80220United States
# Maximum Headshop1832 S BroadwayDenver CO 80210United States
# C:\ProgramData\Anaconda6\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Highland Massage Company5110 W 38th AveDenver CO 80212United States
# VaporCore2120 S Broadway Unit GDenver CO 80210United States
# Speedy Mart1645 E EvansDenver CO 80210United States
# Cultivated Hemp6117 W 38th AveWheat Ridge CO 80033United States
# Dragon Headz1695 Wadsworth Blvd # BLakewood CO 80214United States
# ...

# %%
dfB=dfA[:]
dfB['4f']=''
dfB['5g']=''
dfB
# Out:
# C:\ProgramData\Anaconda6\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda6\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      0                                                  1  \
# 2  NaN  Hush Vapor1908 E Colfax AveDenver CO 80206Unit...
# 4  NaN  Karmaceuticals4 S Santa Fe DrDenver CO 80233Un...
# ...

# %%
for i in range(0,len(dfB[1])):
    
    f=dfB.iloc[i,1]
    Tlen=len(f)
    print(Tlen)
    
    l=dfB.iloc[i,2]
    ilen=len(l)
    print(ilen)
    x=f[ilen:]
    print(f)
    print(x)
    dfB.iloc[i,5]=x
#     print(y)
dfB
# Out:
# 55
# 10
# Hush Vapor1908 E Colfax AveDenver CO 80206United States
# 1908 E Colfax AveDenver CO 80206United States
# 57
# 14
# Karmaceuticals4 S Santa Fe DrDenver CO 80233United States
# 4 S Santa Fe DrDenver CO 80233United States
# 49
# 4
# Lush2490 W 2nd AvenueDenver CO 80223United States
# 2490 W 2nd AvenueDenver CO 80223United States
# 56
# 11
# Herbal Daze4530 E Colfax AveDenver CO 80220United States
# 4530 E Colfax AveDenver CO 80220United States
# 59
# 16
# Maximum Headshop1832 S BroadwayDenver CO 80210United States
# 1832 S BroadwayDenver CO 80210United States
# 67
# 24
# Highland Massage Company5110 W 38th AveDenver CO 80212United States
# 5110 W 38th AveDenver CO 80212United States
# 59
# 9
# VaporCore2120 S Broadway Unit GDenver CO 80210United States
# 2120 S Broadway Unit GDenver CO 80210United States
# 51
# 11
# Speedy Mart1645 E EvansDenver CO 80210United States
# 1645 E EvansDenver CO 80210United States
# 63
# 15
# ...

# %%
dfB
# Out:
#      0                                                  1  \
# 2  NaN  Hush Vapor1908 E Colfax AveDenver CO 80206Unit...
# 4  NaN  Karmaceuticals4 S Santa Fe DrDenver CO 80233Un...
# 6  NaN  Lush2490 W 2nd AvenueDenver CO 80223United States
# 8  NaN  Herbal Daze4530 E Colfax AveDenver CO 80220Uni...
# 10 NaN  Maximum Headshop1832 S BroadwayDenver CO 80210...
# 12 NaN  Highland Massage Company5110 W 38th AveDenver ...
# 14 NaN  VaporCore2120 S Broadway Unit GDenver CO 80210...
# 16 NaN  Speedy Mart1645 E EvansDenver CO 80210United S...
# 18 NaN  Cultivated Hemp6117 W 38th AveWheat Ridge CO 8...
# 20 NaN  Dragon Headz1695 Wadsworth Blvd # BLakewood CO...
# 22 NaN  theCLOUDS vape shop and hookah lounge – Kratom...
# 24 NaN  Canna World Market1420 S Wadsworth BlvdLakewoo...
# 26 NaN  Payless Tobacco in Arvada6385 Wadsworth BlvdAr...
# 28 NaN  The Pipe Shop – Westminster7530 Sheridan Boule...
# 30 NaN  Reflections Salon and Spa980 Simms StGolden CO...
# ...

# %%
dfC=dfB[[1,'3s','5g']]
dfC
# Out:
#                                                     1  \
# 2   Hush Vapor1908 E Colfax AveDenver CO 80206Unit...
# 4   Karmaceuticals4 S Santa Fe DrDenver CO 80233Un...
# 6   Lush2490 W 2nd AvenueDenver CO 80223United States
# 8   Herbal Daze4530 E Colfax AveDenver CO 80220Uni...
# 10  Maximum Headshop1832 S BroadwayDenver CO 80210...
# 12  Highland Massage Company5110 W 38th AveDenver ...
# 14  VaporCore2120 S Broadway Unit GDenver CO 80210...
# 16  Speedy Mart1645 E EvansDenver CO 80210United S...
# 18  Cultivated Hemp6117 W 38th AveWheat Ridge CO 8...
# 20  Dragon Headz1695 Wadsworth Blvd # BLakewood CO...
# 22  theCLOUDS vape shop and hookah lounge – Kratom...
# 24  Canna World Market1420 S Wadsworth BlvdLakewoo...
# 26  Payless Tobacco in Arvada6385 Wadsworth BlvdAr...
# 28  The Pipe Shop – Westminster7530 Sheridan Boule...
# 30  Reflections Salon and Spa980 Simms StGolden CO...
# 32  Golden Leaf8370 Sheridan BoulevardWestminister...
# ...

# %%
dfC.to_excel('test_out.xlsx')
